# %% [markdown]
# **Learning Rate Graph**

# %%
import numpy as np 
import matplotlib.pyplot as plt 

#Plot width / height
fig, ax = plt.subplots(figsize = (16,10), dpi=150)

#data and labels
#Value_sets = ['0.1','0.01','0.001','0.0001','0.00001']
#spectrograms_Accuracies = [54.14,54.21,99.06,93.35,84.14]
#rawSignals_Accuracies = [53.75,54.14,75.93,75.19,70.85]

Value_sets = ['0.00001','0.0001','0.001','0.01','0.1']
spectrograms_Accuracies = [84.14,93.35,99.06,54.21,54.14]
rawSignals_Accuracies = [70.85,75.19,75.93,54.14,53.75]

#Plotting lines
plt.plot(Value_sets, rawSignals_Accuracies,label ='Raw Siganls',marker='o')
plt.plot(Value_sets, spectrograms_Accuracies,'-',label ='Spectrograms',marker='o')

#plot labels
#plt.title('Learning Rate')
plt.xlabel('Learning Rate', fontsize=21)
plt.ylabel('Accuracy (%)', fontsize=21)
plt.legend(fontsize=21)

plt.xticks(fontsize=21)
plt.yticks(fontsize=21)

#data point labeling
for i,j in zip(Value_sets,rawSignals_Accuracies):
    plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
                 xytext=(0,-20), # distance from text to points (x,y)
                 ha='center',size=25)

for i,j in zip(Value_sets,spectrograms_Accuracies):
    plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
                 xytext=(0,5.0), # distance from text to points (x,y)
                 ha='center',size=25)
    
# Display

#plt.tight_layout(pad=2.5)
#plt.show()

#Saving image
plt.savefig("/content/learning_rate_line_graph.png",dpi=600, bbox_inches='tight',pad_inches = 0.12)

# %% [markdown]
# **Data Analytics and Convergence Trend**

# %%
# Import Library
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib.patches import FancyBboxPatch
from matplotlib.ticker import ScalarFormatter
import matplotlib.scale as s

#Plot width / height
fig, ax = plt.subplots(figsize = (23,10.0), dpi=150)

#SUB PLOT  1
plt.subplot(1, 2, 1)

#plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9, top=0.9, wspace=0.9, hspace=0.4)


# Define Data and labels
metrics = ['Accuracy (%)','Precision (%)','Loss (%)']
spectrograms = [99.06, 100, 0.041]
raw_signals = [76.95, 80.29, 0.453]

x_axis = np.arange(len(metrics))


# Multi bar Chart

plt.bar(x_axis -0.2, spectrograms, width=0.4, label = 'Spectrograms',color='#FF7F0E')
plt.bar(x_axis +0.2, raw_signals, width=0.4, label = 'Raw Signals',color='#1F77B4')

# Xticks

plt.xticks(x_axis, metrics,fontsize=23)
plt.yticks(fontsize=23)


# Add labels

#plt.xlabel("Performance Metrics", fontsize=23)
plt.ylabel("Statistics (Log Scale)", fontsize=23)
plt.title('(a)  Datasets Analytics', fontsize=23)

# Add legend
plt.legend(fontsize=21)


#Round the corners
new_patches = []
for patch in reversed(ax.patches): 
  bb = patch.get_bbox() 
  color=patch.get_facecolor() 
  p_bbox = FancyBboxPatch((bb.xmin, bb.ymin), abs(bb.width), abs(bb.height), boxstyle="round,pad=-0.0010,rounding_size=0.18", ec="none", fc=color, mutation_aspect=4 ) 
  patch.remove() 
  new_patches.append(p_bbox)
  

for patch in new_patches: ax.add_patch(patch)

plt.yscale('log')
plt.gca().yaxis.set_major_formatter(ScalarFormatter())

# Display

#plt.tight_layout(pad=3.0)
#plt.show()


#SUB PLOT 2
plt.subplot(1, 2, 2)

#Define data and labels
Value_sets = ['1','50','100','200','300','400','450','500']
spectrograms_Accuracies = [50.23,88.51,92.50,96.01,97.50,98.75,99.06,99.06]
rawSignals_Accuracies = [48.28,68.35,72.42,75.78,75.93,75.93,75.93,75.93]

#Plot the bars
plt.plot(Value_sets, rawSignals_Accuracies,label ='Raw Siganls',marker='o')
plt.plot(Value_sets, spectrograms_Accuracies,'-',label ='Spectrograms',marker='o')

#Plot labels
plt.title('(b)  Validation Accuracy', fontsize=23)
plt.xlabel('No. of Epochs', fontsize=23)
plt.ylabel('Accuracy (%)', fontsize=23)

#define legend
plt.legend(fontsize=23)

plt.xticks(fontsize=23)
plt.yticks(fontsize=23)


#labelling line data points
for i,j in zip(Value_sets,rawSignals_Accuracies):
    plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
                 xytext=(0,-23.0), # distance from text to points (x,y)
                 ha='center',size=27)  #7.9

for i,j in zip(Value_sets,spectrograms_Accuracies):
    plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
                 xytext=(0,8.0), # distance from text to points (x,y)
                 ha='center',size=27)  #8.3
    

# Display
plt.tight_layout(pad=2.5)
#plt.show()

#saving image
plt.savefig("/content/bar-line_datasetsAnalytics_Convergence.png",dpi=600, bbox_inches='tight',pad_inches = 0.12)

# %% [markdown]
# **Sampling Rate**

# %%
#import library
import matplotlib.pyplot as plt

#define plot positions 
fig, ax = plt.subplots(figsize = (16,10), dpi=150)

#define data
Value_sets = ['25','50','100','200','400','600','800','1K']
Accuracies = [69.14,85.78,99.06,71.32,82.34,66.32,81,64.21]


#plot the data
plt.plot(Value_sets, Accuracies,'-',label ='Spectrograms',marker='o',color='#FF7F0E')

#labels
#plt.title('Sampling Rate')
plt.xlabel('Sampling Rate (Hz)', fontsize=21)
plt.ylabel('Accuracy (%)', fontsize=21)

plt.xticks(fontsize=21)
plt.yticks(fontsize=21)


#define legend
plt.legend(fontsize=21)

#labeling line data points
for i,j in zip(Value_sets,Accuracies):
    plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
                 xytext=(0,3.5), # distance from text to points (x,y)
                 ha='center',size=25)

#Data display and save
#plt.show()
plt.savefig("/content/sampling_rate_accuracy.png",dpi=600, bbox_inches='tight',pad_inches = 0.12)

# %%
#import library
import matplotlib.pyplot as plt

#define plot positions 
fig, ax = plt.subplots(figsize = (16,10), dpi=150)

#define data
Value_sets = ['25','50','100']
Accuracies = [69.14,85.78,99.06]


#plot the data
plt.plot(Value_sets, Accuracies,'-',label ='Spectrograms',marker='o',color='#FF7F0E')

#labels
#plt.title('Sampling Rate')
plt.xlabel('Sampling Rate (Hz)', fontsize=21)
plt.ylabel('Accuracy (%)', fontsize=21)

plt.xticks(fontsize=21)
plt.yticks(fontsize=21)


#define legend
plt.legend(fontsize=21)

#labeling line data points
for i,j in zip(Value_sets,Accuracies):
    if j == 99.06:
      plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
        xytext=(0,3.5), color='#FF3333',# distance from text to points (x,y)
        ha='center',size=25)
    else: 
      plt.annotate(str(j), (i, j),textcoords="offset points", # how to position the text
        xytext=(0,3.5), # distance from text to points (x,y)
        ha='center',size=25)
    
#plt.yticks([99.06],["Original"])
highlight = [[99.06,99.06]]
#plt.scatter(*highlight, marker='v', color='r')
#plt.plot(99.06, 99.06, marker='o')


font_sizes = [21,21,22]

for tick, size in zip(plt.xticks()[-1], font_sizes):
    if size == 22:
    #tick.set_fontsize(size)
      tick.set_color('red')

#Data display and save
#plt.show()
plt.savefig("/content/sampling_rate_accuracy.png",dpi=600, bbox_inches='tight',pad_inches = 0.12)

# %%
# Import Library

import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib.patches import FancyBboxPatch


#plot axis or positions
fig, ax = plt.subplots(figsize = (16.5,12.5),dpi=100)
plt.rc('xtick', labelsize=12.5)
plt.rc('ytick', labelsize=12)
# Define Data
datasets = ['Raw Signals', 'Spectrograms']

size_cpu=(2.89, 2.81)
size_cpu_label=(2.89, 2.81)

size_gpu=(4.58, 4.58)
size_gpu_label=(4.58, 4.58)

sizes_memory = (58.8, 29.3)
sizes_memory_labels = (58.8, 29.3)


# Draw first subplot

plt.subplot(2, 3, 1)

#define y limit
plt.ylim(2.5,3.0)

#plot the bar
plt.bar(datasets,size_cpu,width=0.8,color=['#1F77B4', '#FF7F0E'])
#labeling data points
for index,data in enumerate(size_cpu_label):
    plt.text(x=index , y =data-0.04, s=f"{data} GB",horizontalalignment='center', fontdict=dict(fontsize=25,color='white',weight="bold"))

plt.text(-0.73,3.015,"(a)", fontdict=dict(fontsize=21))
plt.title('CPU Memory Consumption', fontdict=dict(fontsize=21))
plt.ylabel('Memory (GB)', fontdict=dict(fontsize=21))

plt.xticks(fontsize=21)
plt.yticks(fontsize=21)


# Draw second subplot

plt.subplot(2, 3, 2)

plt.bar(datasets,size_gpu,width=0.8,color=['#1F77B4', '#FF7F0E'])
#labeling data points
for index,data in enumerate(size_gpu_label):
    plt.text(x=index , y =data-0.4, s=f"{data} GB",horizontalalignment='center', fontdict=dict(fontsize=25,color='white',weight="bold"))

plt.text(-0.67,4.9,"(b)", fontdict=dict(fontsize=21))
plt.title('GPU Memory Consumption', fontdict=dict(fontsize=21))
plt.ylabel('Memory (GB)', fontdict=dict(fontsize=21))

plt.xticks(fontsize=21)
plt.yticks(fontsize=21)


# Draw third subplot

plt.subplot(2, 3, 3)

plt.bar(datasets,sizes_memory,width=0.8,color=['#1F77B4', '#FF7F0E'])
#labeling data points
for index,data in enumerate(sizes_memory_labels):
    plt.text(x=index , y =data-4.5, s=f"{data} MB",horizontalalignment='center', fontdict=dict(fontsize=25,color='white',weight="bold"))

plt.text(-0.80,63,"(c)", fontdict=dict(fontsize=25))
plt.title('Physical Memory Consumption', fontdict=dict(fontsize=21))
plt.ylabel('Memory (MB)', fontdict=dict(fontsize=21))

plt.xticks(fontsize=21)
plt.yticks(fontsize=21)

#Data Display
#plt.show()
plt.tight_layout(pad=2.0)

#Save image
plt.savefig("/content/memory_consumption_1.png",dpi=600, bbox_inches='tight',pad_inches = 0.12)
